# %% [markdown]
# # CCD Image Reduction Tutorial
#
# This notebook is part of a tutorial series adapted from the [Astropy CCD Reduction and Photometry Guide](https://www.astropy.org/ccd-reduction-and-photometry-guide/).
#
# In this part of the series, we will cover:
# - - Understanding the structure of a FITS image
# - - Inspecting metadata and visualizing image data
# - - What is a bias frame?
# - - How to subtract a master bias from a science image
# - - Understanding dark current
# - - Subtracting a dark frame using CCDData
# - - Importance of flat field correction
# - - Applying flat fielding using CCDData and calibration frames

# %%
# Code examples go here
